# %%
import requests as req
import pandas as pd
import xmltodict
from incf.countryutils import transformations
import numpy as np
from collections import defaultdict
import time
import pickle

# %%
resp = req.get('https://musicbrainz.org/ws/2/artist/cc197bad-dc9c-440d-a5b5-d52ba2e14234?inc=tags%20ratings')

# %%
artist = xmltodict.parse(resp.text)['metadata']['artist']

# %%
artist
# Out:
# OrderedDict([(u'@type-id', u'e431f5f6-b5d2-343d-8b36-72607fffb74b'),
#              (u'@type', u'Group'),
#              (u'@id', u'cc197bad-dc9c-440d-a5b5-d52ba2e14234'),
#              (u'name', u'Coldplay'),
#              (u'sort-name', u'Coldplay'),
#              (u'isni-list', OrderedDict([(u'isni', u'000000011551394X')])),
#              (u'country', u'GB'),
#              (u'area',
#               OrderedDict([(u'@id', u'8a754a16-0027-3a29-b6d7-2b40ea0481ed'),
#                            (u'name', u'United Kingdom'),
#                            (u'sort-name', u'United Kingdom'),
#                            (u'iso-3166-1-code-list',
#                             OrderedDict([(u'iso-3166-1-code', u'GB')]))])),
#              (u'begin-area',
#               OrderedDict([(u'@id', u'f03d09b3-39dc-4083-afd6-159e3f0d462f'),
#                            (u'name', u'London'),
#                            (u'sort-name', u'London')])),
#              (u'life-span', OrderedDict([(u'begin', u'1996-09')])),
#              (u'tag-list',
#               OrderedDict([(u'tag',
#                             [OrderedDict([(u'@count', u'7'),
#                                           (u'name', u'alternative rock')]),
#                              OrderedDict([(u'@count', u'1'),
#                                           (u'name', u'ambient pop')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'britannique')]),
#                              OrderedDict([(u'@count', u'5'),
#                                           (u'name', u'british')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'britpop')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'chapel')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'english')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'parlophone')]),
#                              OrderedDict([(u'@count', u'1'),
#                                           (u'name', u'piano pop')]),
#                              OrderedDict([(u'@count', u'3'),
#                                           (u'name', u'piano rock')]),
#                              OrderedDict([(u'@count', u'3'),
#                                           (u'name', u'pop')]),
#                              OrderedDict([(u'@count', u'2'),
#                                           (u'name', u'pop rock')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'pop/rock')]),
#                              OrderedDict([(u'@count', u'1'),
#                                           (u'name', u'post-britpop')]),
#                              OrderedDict([(u'@count', u'4'),
#                                           (u'name', u'rock')]),
#                              OrderedDict([(u'@count', u'0'),
#                                           (u'name', u'rock and indie')]),
#                              OrderedDict([(u'@count', u'2'),
#                                           (u'name', u'uk')])])])),
#              (u'rating',
#               OrderedDict([(u'@votes-count', u'24'), ('#text', u'4.35')]))])

# %% [markdown]
# ### Features for Artists
# - Number of users who've listened to them
# - Total plays
# - Plays per listener
# - Average age of listeners
# - Other artists shared on playlists
# - Counts of users per country or region
# - Genre (MB)
# - Last year active (MB)
# - Country (MB)
# - Type (MB)
# - Rating (MB)

# %%
artists_data = pd.read_csv('artists.csv')
profiles_data = pd.read_csv('profiles.csv')
train = pd.read_csv('train.csv')

# %%
def get_region(country):
    
    # TODO Map with more granularity. Especially countries in Asia that are 
    # really middle eastern along with edge cases like South Africa

    cn_to_ctn = {
        'Antarctica': 'Other',
        'Bouvet Island': 'Other',
        'British Indian Ocean Territory': 'Other',
        'Congo, the Democratic Republic of the': 'Africa',
        "Cote D'Ivoire": 'Africa',
        'Heard Island and Mcdonald Islands': 'Oceania',
        'Iran, Islamic Republic of': 'Asia',
        "Korea, Democratic People's Republic of": 'North Korea',
        'Korea, Republic of': 'Asia',
        'Kyrgyzstan': 'Asia',
        'Micronesia, Federated States of': 'Oceania',
        'Palestinian Territory, Occupied': 'Asia',
        'Pitcairn': 'Other',
        'Slovakia': 'Europe',
        'Svalbard and Jan Mayen': 'Europe',
        'Tanzania, United Republic of': 'Africa',
        'United Kingdom': 'Europe',
        'United States': 'North America',
        'Viet Nam': 'Asia',
        'Virgin Islands, British': 'North America',
        'Virgin Islands, U.s.': 'North America',
    }
    
    return cn_to_ctn[country] if country in cn_to_ctn else transformations.cn_to_ctn(country)

# %%
def extract_artistic_features(data):
    
    start = time.clock()
    
    artistic_features = defaultdict(dict)
    iter = 1
    
    users = profiles_data.set_index(['age', 'sex', 'country']).groupby('user').groups
    fan_groups = data.set_index(['user', 'plays']).groupby(['artist']).groups
    
    for artist, fans in fan_groups.iteritems():
        
        artistic_features[artist] = defaultdict(int)        
        for fan, plays in fans:
            
            age, sex, cn = users[fan][0]
            
            # Tally of number of listeners in each major region
            region = get_region(cn)
            artistic_features[artist][region] += 1

            # Listeners by gender
            if sex == sex:  # Sex is defined
                artistic_features[artist][sex] += 1
                artistic_features[artist]['gender_count'] += 1

            # To calculate average age of listeners 
            if age == age: 
                artistic_features[artist]['age_count'] += 1
                artistic_features[artist]['sum_of_ages'] += age

            # Total listeners
            artistic_features[artist]['count'] += 1

            # Total plays
            artistic_features[artist]['total_plays'] += plays  
            
        artistic_features[artist]['average_age'] = artistic_features[artist]['sum_of_ages'] / float(artistic_features[artist]['age_count'])
        artistic_features[artist]['prop_female'] = artistic_features[artist]['f'] / float(artistic_features[artist]['gender_count'])
        artistic_features[artist]['prop_male'] = artistic_features[artist]['m'] / float(artistic_features[artist]['gender_count'])
        for r in ['Africa', 'Antarctica', 'Asia', 'Europe', 'North America', 
                  'North Korea', 'Oceania', 'Other', 'South America']:
            artistic_features[artist][r] = artistic_features[artist][r] / float(artistic_features[artist]['count'])
        
    print(time.clock() - start)
    return artistic_features

# %%
artistic_features = extract_artistic_features(train)
# Out:
# 20.98387

# %%
pickle.dump(artistic_features, open('artistic_features.pkl', 'w'))

# %% [markdown]
# ### TODO
# - Representation of whether or not an artist is 'popular' (maybe just by number of play?)
# - Should the above be conditioning on characteristics of the user?

# %% [markdown]
# #### Feature interactions
# - Artist is similar by Genre to other artists the user listens to
# - Artist appears on playlists with other songs the user listens to how many times
# - User is close to the average age of the listeners for the artist
# - User is in majority gender for the artist
# - User is in same region as artist... Not sure we have this data.
# - User typically listens to artists in same region

# %%
pd.DataFrame(artistic_features)
# Out:
#                000d90ec-d64c-48a1-b775-e726fd240e9f  \
# Africa                                     0.001961
# Antarctica                                 0.000000
# Asia                                       0.017647
# Europe                                     0.868627
# Iran                                            NaN
# North America                              0.078431
# North Korea                                0.000000
# Oceania                                    0.017647
# Other                                      0.001961
# South America                              0.013725
# age_count                                430.000000
# average_age                               23.002326
# count                                    510.000000
# f                                        155.000000
# gender_count                             482.000000
# m                                        327.000000
# prop_female                                0.321577
# prop_male                                  0.678423
# sum_of_ages                             9891.000000
# total_plays                           100111.000000
#
#                000fc734-b7e1-4a01-92d1-f544261b43f5  \
# Africa                                     0.002670
# Antarctica                                 0.000000
# Asia                                       0.054458
# Europe                                     0.532835
# Iran                                            NaN
# North America                              0.312867
# North Korea                                0.000534
# Oceania                                    0.029899
# Other                                      0.001068
# South America                              0.065670
# age_count                               1438.000000
# average_age                               28.566759
# count                                   1873.000000
# f                                        464.000000
# gender_count                            1663.000000
# m                                       1199.000000
# prop_female                                0.279014
# prop_male                                  0.720986
# sum_of_ages                            41079.000000
# total_plays                           541087.000000
#
#                0019749d-ee29-4a5f-ab17-6bfa11deb969  \
# Africa                                     0.002899
# Antarctica                                 0.000000
# Asia                                       0.037681
# Europe                                     0.736232
# Iran                                            NaN
# North America                              0.159420
# North Korea                                0.000000
# Oceania                                    0.040580
# Other                                      0.000000
# South America                              0.023188
# age_count                                490.000000
# average_age                               28.346939
# count                                    690.000000
# f                                        106.000000
# gender_count                             612.000000
# m                                        506.000000
# prop_female                                0.173203
# prop_male                                  0.826797
# sum_of_ages                            13890.000000
# total_plays                           100362.000000
#
#                0039c7ae-e1a7-4a7d-9b49-0cbc716821a6  \
# Africa                                 4.879040e-03
# Antarctica                             2.710578e-04
# Asia                                   3.896456e-02
# Europe                                 4.034018e-01
# Iran                                   2.000000e+00
# North America                          4.668293e-01
# North Korea                            6.776445e-05
# Oceania                                3.679610e-02
# Other                                  8.131734e-04
# South America                          4.784170e-02
# age_count                              1.219700e+04
# average_age                            2.372198e+01
# count                                  1.475700e+04
# f                                      5.206000e+03
# gender_count                           1.360100e+04
# m                                      8.395000e+03
# prop_female                            3.827660e-01
# prop_male                              6.172340e-01
# sum_of_ages                            2.893370e+05
# total_plays                            5.043920e+06
#
#                004e5eed-e267-46ea-b504-54526f1f377d  \
# Africa                                     0.001899
# Antarctica                                 0.000000
# Asia                                       0.075949
# Europe                                     0.686709
# Iran                                       3.000000
# North America                              0.109494
# North Korea                                0.000000
# Oceania                                    0.012658
# Other                                      0.001266
# South America                              0.110127
# age_count                               1331.000000
# average_age                               26.175056
# count                                   1580.000000
# f                                        382.000000
# gender_count                            1494.000000
# m                                       1112.000000
# prop_female                                0.255689
# prop_male                                  0.744311
# sum_of_ages                            34839.000000
# total_plays                           585493.000000
#
#                00565b31-14a3-4913-bd22-385eb40dd13c  \
# Africa                                     0.005155
# Antarctica                                 0.000000
# Asia                                       0.076031
# Europe                                     0.606959
# Iran                                            NaN
# North America                              0.203608
# North Korea                                0.000000
# Oceania                                    0.018041
# Other                                      0.001289
# South America                              0.088918
# age_count                                645.000000
# average_age                               25.548837
# count                                    776.000000
# f                                         73.000000
# gender_count                             718.000000
# m                                        645.000000
# prop_female                                0.101671
# prop_male                                  0.898329
# sum_of_ages                            16479.000000
# total_plays                           277692.000000
#
#                00a9f935-ba93-4fc8-a33a-993abe9c936b  \
# Africa                                 5.475628e-03
# Antarctica                             5.368263e-04
# Asia                                   4.176508e-02
# Europe                                 7.614344e-01
# Iran                                   8.000000e+00
# North America                          1.091905e-01
# North Korea                            0.000000e+00
# Oceania                                1.793000e-02
# Other                                  6.441915e-04
# South America                          6.216448e-02
# age_count                              7.866000e+03
# average_age                            2.284655e+01
# count                                  9.314000e+03
# f                                      2.140000e+03
# gender_count                           8.759000e+03
# m                                      6.619000e+03
# prop_female                            2.443201e-01
# prop_male                              7.556799e-01
# sum_of_ages                            1.797110e+05
# total_plays                            4.044049e+06
#
#                00eeed6b-5897-4359-8347-b8cd28375331  \
# Africa                                     0.003842
# Antarctica                                 0.000384
# Asia                                       0.057626
# Europe                                     0.801767
# Iran                                       2.000000
# North America                              0.063388
# North Korea                                0.000000
# Oceania                                    0.011525
# Other                                      0.001153
# South America                              0.059547
# age_count                               2203.000000
# average_age                               23.949160
# count                                   2603.000000
# f                                        298.000000
# gender_count                            2445.000000
# m                                       2147.000000
# prop_female                                0.121881
# prop_male                                  0.878119
# sum_of_ages                            52760.000000
# total_plays                           869742.000000
#
#                0103c1cc-4a09-4a5d-a344-56ad99a77193  \
# Africa                                 8.381503e-03
# Antarctica                             1.445087e-04
# Asia                                   6.560694e-02
# Europe                                 6.367052e-01
# Iran                                   6.000000e+00
# North America                          1.635838e-01
# North Korea                            1.445087e-04
# Oceania                                2.485549e-02
# Other                                  5.780347e-04
# South America                          9.913295e-02
# age_count                              5.934000e+03
# average_age                            2.208595e+01
# count                                  6.920000e+03
# f                                      2.649000e+03
# gender_count                           6.513000e+03
# m                                      3.864000e+03
# prop_female                            4.067250e-01
# prop_male                              5.932750e-01
# sum_of_ages                            1.310580e+05
# total_plays                            1.875211e+06
#
#                0110e63e-0a9b-4818-af8e-41e180c20b9a  \
# Africa                                 7.545390e-03
# Antarctica                             4.715869e-04
# Asia                                   4.197123e-02
# Europe                                 4.656921e-01
# Iran                                   1.000000e+00
# North America                          3.864655e-01
# North Korea                            0.000000e+00
# Oceania                                3.088894e-02
# Other                                  1.414761e-03
# South America                          6.531478e-02
# age_count                              3.411000e+03
# average_age                            2.513955e+01
# count                                  4.241000e+03
# f                                      1.577000e+03
# gender_count                           3.778000e+03
# m                                      2.201000e+03
# prop_female                            4.174166e-01
# prop_male                              5.825834e-01
# sum_of_ages                            8.575100e+04
# total_plays                            1.106089e+06
#
#                                ...                   \
# Africa                         ...
# Antarctica                     ...
# Asia                           ...
# Europe                         ...
# Iran                           ...
# North America                  ...
# North Korea                    ...
# Oceania                        ...
# Other                          ...
# South America                  ...
# age_count                      ...
# average_age                    ...
# count                          ...
# f                              ...
# gender_count                   ...
# m                              ...
# prop_female                    ...
# prop_male                      ...
# sum_of_ages                    ...
# total_plays                    ...
#
#                ff6e677f-91dd-4986-a174-8db0474b1799  \
# Africa                                 7.291952e-03
# Antarctica                             4.557470e-04
# Asia                                   4.119953e-02
# Europe                                 5.230152e-01
# Iran                                   2.000000e+00
# North America                          3.152858e-01
# North Korea                            0.000000e+00
# Oceania                                3.099079e-02
# Other                                  1.367241e-03
# South America                          8.021147e-02
# age_count                              8.621000e+03
# average_age                            2.468913e+01
# count                                  1.097100e+04
# f                                      3.149000e+03
# gender_count                           9.986000e+03
# m                                      6.837000e+03
# prop_female                            3.153415e-01
# prop_male                              6.846585e-01
# sum_of_ages                            2.128450e+05
# total_plays                            3.065397e+06
#
#                ff7f80cd-05c2-4068-a00e-fbfbd453d049  \
# Africa                                     0.002273
# Antarctica                                 0.000000
# Asia                                       0.003409
# Europe                                     0.971591
# Iran                                            NaN
# North America                              0.012500
# North Korea                                0.000000
# Oceania                                    0.002273
# Other                                      0.000000
# South America                              0.007955
# age_count                                758.000000
# average_age                               22.428760
# count                                    880.000000
# f                                        231.000000
# gender_count                             835.000000
# m                                        604.000000
# prop_female                                0.276647
# prop_male                                  0.723353
# sum_of_ages                            17001.000000
# total_plays                           400428.000000
#
#                ff865aa0-4603-4f79-ae8b-8735332e2cfa  \
# Africa                                     0.012203
# Antarctica                                 0.000610
# Asia                                       0.075046
# Europe                                     0.352654
# Iran                                       2.000000
# North America                              0.440513
# North Korea                                0.000000
# Oceania                                    0.052471
# Other                                      0.001220
# South America                              0.064063
# age_count                               1361.000000
# average_age                               21.969140
# count                                   1639.000000
# f                                        629.000000
# gender_count                            1546.000000
# m                                        917.000000
# prop_female                                0.406856
# prop_male                                  0.593144
# sum_of_ages                            29900.000000
# total_plays                           424261.000000
#
#                ff95eb47-41c4-4f7f-a104-cdc30f02e872  \
# Africa                                     0.006423
# Antarctica                                 0.000000
# Asia                                       0.039342
# Europe                                     0.458450
# Iran                                            NaN
# North America                              0.431955
# North Korea                                0.000000
# Oceania                                    0.038137
# Other                                      0.000401
# South America                              0.025291
# age_count                               1876.000000
# average_age                               27.163646
# count                                   2491.000000
# f                                        358.000000
# gender_count                            2183.000000
# m                                       1825.000000
# prop_female                                0.163995
# prop_male                                  0.836005
# sum_of_ages                            50959.000000
# total_plays                           637150.000000
#
#                ff9deaae-da4f-42b7-a19e-36fedd3fc706  \
# Africa                                     0.003683
# Antarctica                                 0.000921
# Asia                                       0.036832
# Europe                                     0.292818
# Iran                                            NaN
# North America                              0.540516
# North Korea                                0.000000
# Oceania                                    0.064457
# Other                                      0.000921
# South America                              0.059853
# age_count                                876.000000
# average_age                               24.778539
# count                                   1086.000000
# f                                        484.000000
# gender_count                            1003.000000
# m                                        519.000000
# prop_female                                0.482552
# prop_male                                  0.517448
# sum_of_ages                            21706.000000
# total_plays                           211586.000000
#
#                ffb18e19-64a4-4a65-b4ce-979e00c3c69d  \
# Africa                                     0.005900
# Antarctica                                 0.000492
# Asia                                       0.074730
# Europe                                     0.444444
# Iran                                            NaN
# North America                              0.427729
# North Korea                                0.000000
# Oceania                                    0.022124
# Other                                      0.002950
# South America                              0.021632
# age_count                               1636.000000
# average_age                               24.780562
# count                                   2034.000000
# f                                        521.000000
# gender_count                            1857.000000
# m                                       1336.000000
# prop_female                                0.280560
# prop_male                                  0.719440
# sum_of_ages                            40541.000000
# total_plays                           525198.000000
#
#                ffb2d3e3-a4cc-48cf-8fb0-f2f846e9d7b9  \
# Africa                                 2.220577e-03
# Antarctica                             3.700962e-04
# Asia                                   2.516654e-02
# Europe                                 9.137676e-01
# Iran                                            NaN
# North America                          4.219097e-02
# North Korea                            0.000000e+00
# Oceania                                4.071058e-03
# Other                                  3.700962e-04
# South America                          1.184308e-02
# age_count                              2.169000e+03
# average_age                            2.410558e+01
# count                                  2.702000e+03
# f                                      8.270000e+02
# gender_count                           2.432000e+03
# m                                      1.605000e+03
# prop_female                            3.400493e-01
# prop_male                              6.599507e-01
# sum_of_ages                            5.228500e+04
# total_plays                            1.335281e+06
#
#                ffb390b8-8df4-4b72-97d1-7b2fc008a452  \
# Africa                                     0.002060
# Antarctica                                 0.000000
# Asia                                       0.028846
# Europe                                     0.326236
# Iran                                            NaN
# North America                              0.482143
# North Korea                                0.000000
# Oceania                                    0.054945
# Other                                      0.000000
# South America                              0.105769
# age_count                               1257.000000
# average_age                               18.881464
# count                                   1456.000000
# f                                        857.000000
# gender_count                            1366.000000
# m                                        509.000000
# prop_female                                0.627379
# prop_male                                  0.372621
# sum_of_ages                            23734.000000
# total_plays                           465462.000000
#
#                ffe16bba-4d84-409b-8f22-5242c60b930f  \
# Africa                                     0.000000
# Antarctica                                 0.000000
# Asia                                       0.037300
# Europe                                     0.179396
# Iran                                            NaN
# North America                              0.740675
# North Korea                                0.000000
# Oceania                                    0.035524
# Other                                      0.001776
# South America                              0.005329
# age_count                                485.000000
# average_age                               21.894845
# count                                    563.000000
# f                                        255.000000
# gender_count                             527.000000
# m                                        272.000000
# prop_female                                0.483871
# prop_male                                  0.516129
# sum_of_ages                            10619.000000
# total_plays                           151544.000000
#
#                ffe9ec08-6b6b-4993-9394-e280b429dbfd
# Africa                                     0.010152
# Antarctica                                 0.000000
# Asia                                       0.075417
# Europe                                     0.651922
# Iran                                       1.000000
# North America                              0.218274
# North Korea                                0.000000
# Oceania                                    0.032632
# Other                                      0.001450
# South America                              0.009427
# age_count                               1129.000000
# average_age                               24.229407
# count                                   1379.000000
# f                                        218.000000
# gender_count                            1263.000000
# m                                       1045.000000
# prop_female                                0.172605
# prop_male                                  0.827395
# sum_of_ages                            27355.000000
# total_plays                           384695.000000
#
# [20 rows x 2000 columns]
